# %% [markdown]
# Instalación e importación de librerías

# %%
print("fg")
# Out:
# fg

# %%
# !pip install opencv-python
# !pip install matplotlib
# !pip install tensorflow==2.1.0
# !pip install pillow

# %%
import os
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# Carga de DATA

# %%
dir_entreno = 'C:/Users/PAUL/Desktop/jupyter/dataset/'
dir_entreno_mas = os.path.join(dir_entreno, 'con_mascara')
dir_entreno_no_mas = os.path.join(dir_entreno, 'sin_mascara')

# %%
entreno_masc_fnames = os.listdir( dir_entreno_mas )
entreno_no_masc_fnames = os.listdir( dir_entreno_no_mas )
print(entreno_masc_fnames[:10])
print(entreno_no_masc_fnames[:10])
# Out:
# ['0_0_0 copy 10.jpg', '0_0_0 copy 11.jpg', '0_0_0 copy 12.jpg', '0_0_0 copy 13.jpg', '0_0_0 copy 14.jpg', '0_0_0 copy 15.jpg', '0_0_0 copy 16.jpg', '0_0_0 copy 17.jpg', '0_0_0 copy 18.jpg', '0_0_0 copy 19.jpg']
# ['0.jpg', '0_0_aidai_0014.jpg', '0_0_aidai_0029.jpg', '0_0_aidai_0043.jpg', '0_0_aidai_0074.jpg', '0_0_aidai_0084.jpg', '0_0_aidai_0136.jpg', '0_0_anhu_0004.jpg', '0_0_anhu_0020.jpg', '0_0_anhu_0025.jpg']

# %%
print('Total imagenes con mascara: ', len(os.listdir( dir_entreno_mas ) ))
print('Total imagenes sin mascara: ', len(os.listdir( dir_entreno_no_mas ) ))
# Out:
# Total imagenes con mascara:  1916
# Total imagenes sin mascara:  1930

# %% [markdown]
# Se genera un modelo con 3 capas de convolución

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    #clasifica si hay o no
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(lr=0.001),
            loss = 'binary_crossentropy',
            metrics = ['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
img_height = 150
img_width = 150
batch_size = 10
train_datagen = ImageDataGenerator(rescale = 1./255,
            shear_range=0.2,
            zoom_range=0.2,
            horizontal_flip=True,
            validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
            dir_entreno,
            target_size=(img_height, img_width),
            batch_size=batch_size,
            class_mode='binary',
            subset='training'
)

validation_generator = train_datagen.flow_from_directory(
            dir_entreno,
            target_size=(img_height, img_width),
            batch_size=batch_size,
            class_mode='binary',
            subset='validation'
)
# Out:
# Found 3077 images belonging to 2 classes.
# Found 769 images belonging to 2 classes.

# %%
nb_epochs = 10
history = model.fit_generator(
                    train_generator,
                    steps_per_epoch = train_generator.samples // batch_size,
                    validation_data = validation_generator,
                    validation_steps = validation_generator.samples // batch_size,
                    epochs = nb_epochs
)
# Out:
# WARNING:tensorflow:From <ipython-input-16-12076e9b9f76>:7: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 307 steps, validate for 76 steps
# Epoch 1/10
# 239/307 [======================>.......] - ETA: 42s - loss: 0.3834 - accuracy: 0.8538
# C:\Users\PAUL\.conda\envs\iaaEnv\lib\site-packages\PIL\Image.py:961: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 307/307 [==============================] - 214s 697ms/step - loss: 0.3597 - accuracy: 0.8611 - val_loss: 0.2062 - val_accuracy: 0.9382
# Epoch 2/10
# 307/307 [==============================] - 159s 517ms/step - loss: 0.2394 - accuracy: 0.9120 - val_loss: 0.1998 - val_accuracy: 0.8987
# Epoch 3/10
# 307/307 [==============================] - 143s 466ms/step - loss: 0.1927 - accuracy: 0.9260 - val_loss: 0.1386 - val_accuracy: 0.9447
# Epoch 4/10
# 307/307 [==============================] - 155s 505ms/step - loss: 0.1768 - accuracy: 0.9306 - val_loss: 0.1532 - val_accuracy: 0.9579
# Epoch 5/10
# 307/307 [==============================] - 143s 466ms/step - loss: 0.1498 - accuracy: 0.9449 - val_loss: 0.1144 - val_accuracy: 0.9697
# Epoch 6/10
# 307/307 [==============================] - 141s 460ms/step - loss: 0.1421 - accuracy: 0.9466 - val_loss: 0.0866 - val_accuracy: 0.9671
# Epoch 7/10
# 307/307 [==============================] - 143s 465ms/step - loss: 0.1261 - accuracy: 0.9534 - val_loss: 0.1014 - val_accuracy: 0.9671
# Epoch 8/10
# 307/307 [==============================] - 159s 519ms/step - loss: 0.1119 - accuracy: 0.9563 - val_loss: 0.1231 - val_accuracy: 0.9553
# Epoch 9/10
# 307/307 [==============================] - 176s 574ms/step - loss: 0.1017 - accuracy: 0.9619 - val_loss: 0.2244 - val_accuracy: 0.9092
# Epoch 10/10
# 307/307 [==============================] - 148s 481ms/step - loss: 0.0800 - accuracy: 0.9739 - val_loss: 0.0908 - val_accuracy: 0.9697

# %%
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from PIL import Image
import numpy as np

# %%
vc = cv2.VideoCapture(0)
plt.ion()
if vc.isOpened(): 
    is_capturing, frame = vc.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    
    webcam_preview = plt.imshow(frame)    
else:
    is_capturing = False

while is_capturing:
    try:    
        is_capturing, frame = vc.read()
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    
        frame_res = cv2.resize(frame, dsize=(150, 150), interpolation=cv2.INTER_CUBIC)
        x=image.img_to_array(frame_res)
        x=np.expand_dims(x, axis=0)
        images = np.vstack([x])
        classes = model.predict(images, batch_size=10)
        if classes[0]>0:
            print("No Lleva mascara")
        else:
            print("Si lleva mascara")
            print("Puede pasar normalon al metro")
        webcam_preview = plt.imshow(frame)
        try:    
            plt.pause(1)
        except Exception:
            pass
    except KeyboardInterrupt:
        vc.release()
# Out:
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# Si lleva mascara
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-19-51f5cfb3c3d4> in <module>
#      11     try:
#      12         is_capturing, frame = vc.read()
# ---> 13         frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      14         frame_res = cv2.resize(frame, dsize=(150, 150), interpolation=cv2.INTER_CUBIC)
#      15         x=image.img_to_array(frame_res)
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-2b5g8ysb\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
